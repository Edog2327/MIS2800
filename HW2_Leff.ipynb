# %% [markdown]
# <a href="https://colab.research.google.com/github/Edog2327/MIS2800/blob/main/HW2_Leff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# in the blank, complete the code below to import SQLlite3 into Colab
import sqlite3

# %%
#create HW3_AFC_North_APPG.db in temporary Colab local storage
conn = sqlite3.connect ("HW2_AFC_North_APPG.db")

# %%
#create a strict table named HW_AFC_North_APPG
#the table should include the following information: team_name, coach, wins, losses, ties
#define the data type for each column
#team_name should be the primary key
conn.execute('''
DROP TABLE IF EXISTS HW2_AFC_North_APPG;
CREATE TABLE HW2_AFC_North_APPG(
  team_name TEXT PRIMARY KEY NOT NULL,
  coach TEXT,
  wins INTEGER,
  losses INTEGER,
  ties INTEGER)
  STRICT;
  ''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-1685407066.py in <cell line: 0>()
#       3 #define the data type for each column
#       4 #team_name should be the primary key
# ----> 5 conn.execute('''
#       6 CREATE TABLE HW2_AFC_North_APPG(
#       7   team_name TEXT PRIMARY KEY NOT NULL,
#
# OperationalError: table HW2_AFC_North_APPG already exists

# %%
# adding team stats based on the screenshots above
conn.execute('''
INSERT INTO HW2_AFC_North_APPG (team_name, coach, wins_2025, losses_2025, ties_2025)
VALUES ('Steelers', 'Mike Tomlin', 10, 7, 0),
('Ravens', 'John Harbaugh', 8, 9, 0),
('Bengals', 'Zac Taylor', 6, 11, 0),
('Browns', 'Kevin Stefanski', 5, 12, 0);
''')

# %%
#select all the data where teams had more than 7 wins
query = "SELECT * FROM HW2_AFC_North_APPG WHERE wins_2025 > 7"
results = conn.execute(query)
for row in results:
  print(row)
# Out:
# ('Steelers', 'Mike Tomlin', 10, 7, 0)
# ('Ravens', 'John Harbaugh', 8, 9, 0)

# %%
#Select only the team_name and wins. Sort numercially from highest to lowest based on wins
query = "SELECT team_name, wins_2025 FROM HW2_AFC_North_APPG ORDER BY wins DESC"
for row in conn.execute(query):
  print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-729135408.py in <cell line: 0>()
#       1 #Select only the team_name and wins. Sort numercially from highest to lowest based on wins
#       2 query = "SELECT team_name, wins_2025 FROM HW2_AFC_North_APPG ORDER BY wins DESC"
# ----> 3 for row in conn.execute(query):
#       4   print(row)
#       5
#
# OperationalError: no such column: wins
