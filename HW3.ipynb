# %% [markdown]
# <a href="https://colab.research.google.com/github/Edog2327/MIS2800/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands(brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# Select * from Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# Select brand_name, brand_type from Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
# %%sql
# Select brand_type from Marketing_Brands where brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# %%sql
# SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# %%sql
# Select brand_name FROM Marketing_Brands WHERE brand_budget > 10000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS',)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# --Find the  brands where the brand type is Snacks or Beverages. Display only the brand name
# SELECT brand_name FROM Marketing_Brands WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# -- Sort the table by brand budget in DESC order. Display only the brand_name and brand_budget
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# -- select all columns in ascending order of budget
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: the word Table was not in the block
# 2. How did you fix the error in Block #2? Answer: the block needed INTO and the name of the table Marketing_Brands
# 3. How did you fix the error in Block #3? Answer: the block needed * inbetween Select and from
# 4. How did you fix the error in Block #4? Answer: the block needed Select brand_name, brand_type from Marketing_Brands;
# 5. How did you fix the error in Block #5? Answer: the block needed Select brand_type from Marketing_Brands where brand_type = 'Religious'
# 6. How did you fix the error in Block #6? Answer: the block needed Select brand_name FROM Marketing_Brands WHERE brand_budget > 10000000;
# 7. How did you fix the error in Block #7? Answer: The code ran fine, i couldnt see the full instruction so unsure if I completed it correctly
# 8. How did you fix the error in Block #8? Answer: needed this code, SELECT brand_name FROM Marketing_Brands WHERE brand_type IN ('Snacks', 'Beverages');
# 9. How did you fix the error in Block #9? Answer: needed this code, SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# 10. How did you fix the error in Block #10? Answer: needed this code, SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
